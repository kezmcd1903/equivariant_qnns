# %% [markdown]
# # Classifying Footwear with Reverse Mapping and non-Equivariant QNNs
#
# ## Authors : Kieran McDowall, NQCC. Max Arnott, Zaiku.

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import clear_output
from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.circuit.library import ZFeatureMap
from qiskit.quantum_info import SparsePauliOp
from qiskit_algorithms.optimizers import COBYLA
from qiskit_algorithms.utils import algorithm_globals
from qiskit_machine_learning.algorithms.classifiers import NeuralNetworkClassifier
from qiskit_machine_learning.neural_networks import EstimatorQNN
from sklearn.model_selection import train_test_split
from circuit_layers import conv_circuit, conv_layer, pool_circuit, pool_layer, encode_image_to_quantum
from qiskit_machine_learning.circuit.library import RawFeatureVector
from qiskit.circuit.library import EfficientSU2

algorithm_globals.random_seed = 12345

# %%
from matplotlib import pyplot
from keras.datasets import fashion_mnist
import numpy as np

Map = 'Stereographic'# 'Orthographic', 'Stereographic','Twilight' , 'Gnomonic'
train_size = 200
test_size = 60
M = 1
loss = 'cross_entropy' # 'cross_entropy''squared_error'
repeats = 10


# load dataset
(trainX, trainy), (testX, testy) = fashion_mnist.load_data()
train_indices = []
test_indices = []
train_labels = []
test_labels = []

#selecting only boots and sandals from the dataset
for i in range(len(trainy)):
    if (trainy[i] == 5) or (trainy[i] == 9):
        train_indices.append(i)
    if trainy[i] == 5:
        train_labels.append(1)
    if trainy[i] == 9:
        train_labels.append(-1)
    
# print(len(train_labels))

for i in range(len(testy)):
    if (testy[i] == 5) or (testy[i] == 9): # 5 = sandal, 9 = boot
        test_indices.append(i)
    if testy[i] == 5:
        test_labels.append(1) # 1 = sandal
    if testy[i] == 9:
        test_labels.append(-1) # -1 = boot

    

#resizing
trainX_shoes_small = [trainX[i] for i in train_indices]
trainy_shoes = [trainy[i] for i in train_indices]
testX_shoes_small = [testX[i] for i in test_indices]
testy_shoes = [testy[i] for i in test_indices]

trainy_shoes = [1 if x == 5 else -1 for x in trainy_shoes]
testy_shoes = [1 if x == 5 else -1 for x in testy_shoes]

trainX_shoes = []
for i in range(len(trainX_shoes_small)):
  new_image = np.zeros((32, 32), dtype=trainX_shoes_small[i].dtype)
  new_image[2:-2, 2:-2] = trainX_shoes_small[i]
  trainX_shoes.append(new_image)

testX_shoes = []
for i in range(len(testX_shoes_small)):
  new_image = np.zeros((32, 32), dtype=testX_shoes_small[i].dtype)
  new_image[2:-2, 2:-2] = testX_shoes_small[i]
  testX_shoes.append(new_image)
  

# Define sample size
trainX_shoes = trainX_shoes[0:train_size]
train_labels = train_labels[0:train_size]
testX_shoes = testX_shoes[0:test_size]
test_labels = test_labels[0:test_size]


def pixelate_image(image):
    
    new_image = np.zeros((16, 16))
    
    for i in range(16):
        for j in range(16):
            
            new_image[i, j] = np.mean(image[i*2:(i+1)*2, j*2:(j+1)*2])
    
    return new_image


trainX_shoes16 = []
for i in range(len(trainX_shoes)):
    trainX_shoes16.append(pixelate_image(trainX_shoes[i]))
    

testX_shoes16 = []
for i in range(len(testX_shoes)):
    testX_shoes16.append(pixelate_image(testX_shoes[i])) 

  
import random
indices_to_flip_train = random.sample(range(len(trainX_shoes16)), len(trainX_shoes16) // 2)
indices_to_flip_test = random.sample(range(len(testX_shoes16)), len(testX_shoes16) // 2)

for index in indices_to_flip_train:
    # Flip the image horizontally
    trainX_shoes16[index] = trainX_shoes16[index][:, ::-1]

for index in indices_to_flip_test:
    # Flip the image horizontally
    testX_shoes16[index] = testX_shoes16[index][:, ::-1]

for i in range(9):
 # define subplot
 pyplot.subplot(330 + 1 + i)
 # plot raw pixel data
 pyplot.imshow(trainX_shoes16[i], cmap=pyplot.get_cmap('gray'))
# show the figure
pyplot.show()


print('Training data length is:', len(trainX_shoes16))

print('Test / train split is:', len(testX_shoes16)/len(trainX_shoes16))


#### 1) Need to flatten arrays
trainX_shoes_flat = []
testX_shoes_flat = []

for i in range(len(trainX_shoes16)):
    trainX_shoes_flat.append(trainX_shoes16[i].flatten())

for i in range(len(testX_shoes16)):    
    testX_shoes_flat.append(testX_shoes16[i].flatten())


# testX_shoes_flat[0].shape

# len(testX_shoes_flat)



#### 1.5) Now rescale (if Orthographic)

def normalize(image):
    norm = np.linalg.norm(image)
    return image / norm



def rescale(image,M):
    norm = np.linalg.norm(image)
    #10000

    if norm/M < 1:
        print('Rescale successful')

    else:
        print('Rescale incorrect, norm/M is not less than 1. norm/M =', norm/M)
        
    
    return image / M


trainX_shoes_flat = [rescale(array,M) for array in trainX_shoes_flat]
testX_shoes_flat = [rescale(array,M) for array in testX_shoes_flat]


#### 2) Now remove final coordinate from vectors
# trainX_shoes_flat[0].shape
# testX_shoes_flat
trainX_shoes_flat = [array[:-1] for array in trainX_shoes_flat]
testX_shoes_flat = [array[:-1] for array in testX_shoes_flat]

print('shape before projection',len(trainX_shoes_flat[0]))


#### 3) Apply the reverse map projection
import functools

# Calculate the norm and append it to each array
def inverse_orthographic(x):
    x_0 = np.sqrt( 1 - np.linalg.norm(x)**2)
    return x + [x_0]


def arbitrary_inverse_projection(a, x):
    # a should be the x_0 coordinate of the centre of projection. x belongs to the hyperplane
    s = np.linalg.norm(x)
    
    # this part handles the points which are outside of R_alpha
    if (a < -1) and (s > np.sqrt((a-1)/(a+1))):
        x = [ np.sqrt((a-1)/(a+1)) * x_i/s for x_i in x ]
        s = np.sqrt((a-1)/(a+1))
    
    #quadratic formula
    A = (s**2 + (1-a)**2)
    B = -2*a*s**2
    C = s**2 * a**2 - (1-a)**2
    
    x_0 = (-B + np.sqrt( B**2 - 4*A*C ))/ (2*A)
    
    return [ ((x_0 - a)/(1-a))*x_i for x_i in x ] + [x_0]


inverse_stereographic = functools.partial(arbitrary_inverse_projection, -1)
inverse_gnomonic = functools.partial(arbitrary_inverse_projection, 0)
inverse_twilight = functools.partial(arbitrary_inverse_projection, -1-np.sqrt(2)/2)
#

trainX_shoes_final = []
testX_shoes_final = []


if Map == 'Orthographic':
    # alpha = -oo
    # alpha = -oo
    trainX_shoes_final = [np.append(array, np.sqrt(1-np.linalg.norm(array)**2)) for array in trainX_shoes_flat]   # np.sqrt(1-np.linalg.norm(array)**2)
    testX_shoes_final = [np.append(array, np.sqrt(1-np.linalg.norm(array)**2)) for array in testX_shoes_flat]   #

 
if Map == 'Gnomonic':
    # # alpha = 0
    for i in range(len(trainX_shoes_flat)):
        trainX_shoes_final.append(inverse_gnomonic(trainX_shoes_flat[i]))
        
    for i in range(len(testX_shoes_flat)):
        testX_shoes_final.append(inverse_gnomonic(testX_shoes_flat[i]))
 
if Map == 'Stereographic':
    # alpha = -1
    for i in range(len(trainX_shoes_flat)):
        trainX_shoes_final.append(inverse_stereographic(trainX_shoes_flat[i]))
        
    for i in range(len(testX_shoes_flat)):
        testX_shoes_final.append(inverse_stereographic(testX_shoes_flat[i]))

if Map == 'Twilight':
    # alpha = -1-np.sqrt(2)/2
    for i in range(len(trainX_shoes_flat)):
        trainX_shoes_final.append(inverse_twilight(trainX_shoes_flat[i]))
        
    for i in range(len(testX_shoes_flat)):
        testX_shoes_final.append(inverse_twilight(testX_shoes_flat[i]))



print('shape after projection',len(trainX_shoes_final[0]))


from qiskit import QuantumCircuit, transpile, assemble

def normalize(image):
    norm = np.linalg.norm(image)
    return image / norm

def encode_image_to_quantum(image):
    # Flatten the image to a 1D array
    image = image.flatten()
    
    # Normalize the image pixel values to form a valid quantum state
    normalized_image = normalize(image)
    
    # Initialize a quantum circuit with 4 qubits
    num_qubits = 8
    qc = QuantumCircuit(num_qubits)
    
    # Prepare the quantum state from the normalized pixel values
    qc.initialize(normalized_image, range(num_qubits))
    
    return qc

# Let's see some examples in our dataset
fig, ax = plt.subplots(3, 5, figsize=(15, 10), subplot_kw={"xticks": [], "yticks": []})
for i in range(15):  # Adjusted for 3 rows and 5 columns (3*5 = 15)
    ax[i // 5, i % 5].imshow(np.asarray(testX_shoes_final[i]).reshape(16, 16), aspect="equal")    #, cmap='gray'
plt.subplots_adjust(wspace=0.1, hspace=0.5)
# Out:
# Training data length is: 200
# Test / train split is: 0.3
# Rescale incorrect, norm/M is not less than 1. norm/M = 1898.2375872108316
# Rescale incorrect, norm/M is not less than 1. norm/M = 713.3517715685579
# Rescale incorrect, norm/M is not less than 1. norm/M = 1353.3317682667468
# Rescale incorrect, norm/M is not less than 1. norm/M = 2032.55942410056
# Rescale incorrect, norm/M is not less than 1. norm/M = 925.1525887657668
# Rescale incorrect, norm/M is not less than 1. norm/M = 817.0371396087206
# Rescale incorrect, norm/M is not less than 1. norm/M = 1761.0017923045962
# Rescale incorrect, norm/M is not less than 1. norm/M = 581.0474378224209
# Rescale incorrect, norm/M is not less than 1. norm/M = 1286.4312554505195
# Rescale incorrect, norm/M is not less than 1. norm/M = 1851.66404890304
# Rescale incorrect, norm/M is not less than 1. norm/M = 981.4272769798076
# Rescale incorrect, norm/M is not less than 1. norm/M = 2289.276960090238
# Rescale incorrect, norm/M is not less than 1. norm/M = 1472.3958791710877
# Rescale incorrect, norm/M is not less than 1. norm/M = 654.370355761934
# Rescale incorrect, norm/M is not less than 1. norm/M = 370.57775837197784
# Rescale incorrect, norm/M is not less than 1. norm/M = 1873.0132474171132
# Rescale incorrect, norm/M is not less than 1. norm/M = 788.892974363443
# Rescale incorrect, norm/M is not less than 1. norm/M = 2192.7608596242317
# Rescale incorrect, norm/M is not less than 1. norm/M = 2150.5205474489194
# Rescale incorrect, norm/M is not less than 1. norm/M = 1411.9385388535861
# Rescale incorrect, norm/M is not less than 1. norm/M = 1128.4865140975323
# Rescale incorrect, norm/M is not less than 1. norm/M = 1652.2585678397918
# Rescale incorrect, norm/M is not less than 1. norm/M = 1640.0635658412755
# Rescale incorrect, norm/M is not less than 1. norm/M = 1078.791395497758
# Rescale incorrect, norm/M is not less than 1. norm/M = 1222.5827170379926
# Rescale incorrect, norm/M is not less than 1. norm/M = 750.7160748245637
# Rescale incorrect, norm/M is not less than 1. norm/M = 959.673902948288
# Rescale incorrect, norm/M is not less than 1. norm/M = 1870.0598085355452
# Rescale incorrect, norm/M is not less than 1. norm/M = 624.7067311947263
# Rescale incorrect, norm/M is not less than 1. norm/M = 1767.8175457325906
# Rescale incorrect, norm/M is not less than 1. norm/M = 1419.6486140943468
# Rescale incorrect, norm/M is not less than 1. norm/M = 1794.4512740668106
# Rescale incorrect, norm/M is not less than 1. norm/M = 721.5145961794536
# Rescale incorrect, norm/M is not less than 1. norm/M = 1507.488805928588
# Rescale incorrect, norm/M is not less than 1. norm/M = 1146.3881868721433
# Rescale incorrect, norm/M is not less than 1. norm/M = 849.8192454869447
# Rescale incorrect, norm/M is not less than 1. norm/M = 1011.7425252997919
# Rescale incorrect, norm/M is not less than 1. norm/M = 1069.4071663777086
# Rescale incorrect, norm/M is not less than 1. norm/M = 1072.595916456892
# Rescale incorrect, norm/M is not less than 1. norm/M = 968.0220167950727
# Rescale incorrect, norm/M is not less than 1. norm/M = 1569.7962845541456
# Rescale incorrect, norm/M is not less than 1. norm/M = 1367.138069106409
# Rescale incorrect, norm/M is not less than 1. norm/M = 867.4571315056439
# Rescale incorrect, norm/M is not less than 1. norm/M = 1014.6509867929957
# Rescale incorrect, norm/M is not less than 1. norm/M = 1473.057895162305
# Rescale incorrect, norm/M is not less than 1. norm/M = 703.0183141284443
# Rescale incorrect, norm/M is not less than 1. norm/M = 1060.4440991867511
# Rescale incorrect, norm/M is not less than 1. norm/M = 1861.9949147352686
# Rescale incorrect, norm/M is not less than 1. norm/M = 843.1045679510935
# Rescale incorrect, norm/M is not less than 1. norm/M = 1348.8975127859048
# Rescale incorrect, norm/M is not less than 1. norm/M = 1263.5901234181913
# Rescale incorrect, norm/M is not less than 1. norm/M = 784.4787282010902
# Rescale incorrect, norm/M is not less than 1. norm/M = 896.4459339525167
# Rescale incorrect, norm/M is not less than 1. norm/M = 1544.1866993663687
# Rescale incorrect, norm/M is not less than 1. norm/M = 1961.1045994540934
# Rescale incorrect, norm/M is not less than 1. norm/M = 1639.5757073096686
# Rescale incorrect, norm/M is not less than 1. norm/M = 639.3141833245998
# Rescale incorrect, norm/M is not less than 1. norm/M = 679.2511501646501
# Rescale incorrect, norm/M is not less than 1. norm/M = 1532.1548550978782
# Rescale incorrect, norm/M is not less than 1. norm/M = 737.5566927362262
# Rescale incorrect, norm/M is not less than 1. norm/M = 2305.430897901735
# Rescale incorrect, norm/M is not less than 1. norm/M = 1597.3827617387137
# Rescale incorrect, norm/M is not less than 1. norm/M = 987.274626180578
# Rescale incorrect, norm/M is not less than 1. norm/M = 1090.4001559060785
# Rescale incorrect, norm/M is not less than 1. norm/M = 480.78146022907333
# Rescale incorrect, norm/M is not less than 1. norm/M = 1419.6809720849258
# Rescale incorrect, norm/M is not less than 1. norm/M = 1214.6951520854934
# Rescale incorrect, norm/M is not less than 1. norm/M = 1165.4489210171332
# Rescale incorrect, norm/M is not less than 1. norm/M = 1689.7669217972045
# Rescale incorrect, norm/M is not less than 1. norm/M = 465.29641090384524
# Rescale incorrect, norm/M is not less than 1. norm/M = 1068.4352168007192
# Rescale incorrect, norm/M is not less than 1. norm/M = 627.856323134521
# Rescale incorrect, norm/M is not less than 1. norm/M = 1232.9701689416497
# Rescale incorrect, norm/M is not less than 1. norm/M = 872.7055631769515
# Rescale incorrect, norm/M is not less than 1. norm/M = 1015.6550534014981
# Rescale incorrect, norm/M is not less than 1. norm/M = 898.230900158751
# Rescale incorrect, norm/M is not less than 1. norm/M = 1727.4729375593702
# Rescale incorrect, norm/M is not less than 1. norm/M = 1797.8112734655992
# Rescale incorrect, norm/M is not less than 1. norm/M = 1423.6884534546173
# Rescale incorrect, norm/M is not less than 1. norm/M = 839.4618067547802
# Rescale incorrect, norm/M is not less than 1. norm/M = 1574.2968073079485
# Rescale incorrect, norm/M is not less than 1. norm/M = 1746.3805427225764
# Rescale incorrect, norm/M is not less than 1. norm/M = 1198.9950479464042
# Rescale incorrect, norm/M is not less than 1. norm/M = 2377.5948587806124
# Rescale incorrect, norm/M is not less than 1. norm/M = 942.4167735137146
# Rescale incorrect, norm/M is not less than 1. norm/M = 923.1609759408161
# Rescale incorrect, norm/M is not less than 1. norm/M = 794.3057503254021
# Rescale incorrect, norm/M is not less than 1. norm/M = 1554.6899610533285
# Rescale incorrect, norm/M is not less than 1. norm/M = 989.3226849718953
# Rescale incorrect, norm/M is not less than 1. norm/M = 1708.662671506579
# Rescale incorrect, norm/M is not less than 1. norm/M = 584.3794785924639
# Rescale incorrect, norm/M is not less than 1. norm/M = 1808.3607908821734
# Rescale incorrect, norm/M is not less than 1. norm/M = 1251.2551448445677
# Rescale incorrect, norm/M is not less than 1. norm/M = 1517.2196610906412
# Rescale incorrect, norm/M is not less than 1. norm/M = 1344.6423316257747
# Rescale incorrect, norm/M is not less than 1. norm/M = 1008.7932146877278
# Rescale incorrect, norm/M is not less than 1. norm/M = 1360.3950023798236
# Rescale incorrect, norm/M is not less than 1. norm/M = 1593.6658016974575
# Rescale incorrect, norm/M is not less than 1. norm/M = 1562.8114089678256
# Rescale incorrect, norm/M is not less than 1. norm/M = 1340.2334684673413
# Rescale incorrect, norm/M is not less than 1. norm/M = 1176.2606800790377
# Rescale incorrect, norm/M is not less than 1. norm/M = 1540.4762656399482
# Rescale incorrect, norm/M is not less than 1. norm/M = 779.8270240893169
# Rescale incorrect, norm/M is not less than 1. norm/M = 934.0387103862452
# Rescale incorrect, norm/M is not less than 1. norm/M = 2076.358215120888
# Rescale incorrect, norm/M is not less than 1. norm/M = 1460.2967806237195
# Rescale incorrect, norm/M is not less than 1. norm/M = 1935.0200903349814
# Rescale incorrect, norm/M is not less than 1. norm/M = 1107.589894771526
# Rescale incorrect, norm/M is not less than 1. norm/M = 701.7011472129713
# Rescale incorrect, norm/M is not less than 1. norm/M = 793.2377086977144
# Rescale incorrect, norm/M is not less than 1. norm/M = 1754.4626670294242
# Rescale incorrect, norm/M is not less than 1. norm/M = 740.9164089153378
# Rescale incorrect, norm/M is not less than 1. norm/M = 1208.1327276007385
# Rescale incorrect, norm/M is not less than 1. norm/M = 853.0566364550481
# Rescale incorrect, norm/M is not less than 1. norm/M = 1479.2446974723282
# Rescale incorrect, norm/M is not less than 1. norm/M = 1505.4505762395522
# Rescale incorrect, norm/M is not less than 1. norm/M = 525.9392788145796
# Rescale incorrect, norm/M is not less than 1. norm/M = 1054.0751277779018
# Rescale incorrect, norm/M is not less than 1. norm/M = 1854.118911370034
# Rescale incorrect, norm/M is not less than 1. norm/M = 1777.3061778995761
# Rescale incorrect, norm/M is not less than 1. norm/M = 1890.0108630640195
# Rescale incorrect, norm/M is not less than 1. norm/M = 1223.7127675643496
# Rescale incorrect, norm/M is not less than 1. norm/M = 1101.3187549479032
# Rescale incorrect, norm/M is not less than 1. norm/M = 1417.5293206844083
# Rescale incorrect, norm/M is not less than 1. norm/M = 984.8421827886943
# Rescale incorrect, norm/M is not less than 1. norm/M = 723.226969906405
# Rescale incorrect, norm/M is not less than 1. norm/M = 1698.0153120628802
# Rescale incorrect, norm/M is not less than 1. norm/M = 1589.8412066932974
# Rescale incorrect, norm/M is not less than 1. norm/M = 1799.9742706494446
# Rescale incorrect, norm/M is not less than 1. norm/M = 1698.018827192443
# Rescale incorrect, norm/M is not less than 1. norm/M = 1163.0510521898857
# Rescale incorrect, norm/M is not less than 1. norm/M = 1008.2060491288474
# Rescale incorrect, norm/M is not less than 1. norm/M = 711.5889789759254
# Rescale incorrect, norm/M is not less than 1. norm/M = 1895.3429603900188
# Rescale incorrect, norm/M is not less than 1. norm/M = 1509.3522617334895
# Rescale incorrect, norm/M is not less than 1. norm/M = 812.0775055374949
# Rescale incorrect, norm/M is not less than 1. norm/M = 778.8370336598023
# Rescale incorrect, norm/M is not less than 1. norm/M = 728.971707269905
# Rescale incorrect, norm/M is not less than 1. norm/M = 1211.094675283481
# Rescale incorrect, norm/M is not less than 1. norm/M = 1626.1442125469684
# Rescale incorrect, norm/M is not less than 1. norm/M = 1434.3394385569966
# Rescale incorrect, norm/M is not less than 1. norm/M = 1811.2099719524515
# Rescale incorrect, norm/M is not less than 1. norm/M = 716.8902461325583
# Rescale incorrect, norm/M is not less than 1. norm/M = 391.3385682500512
# Rescale incorrect, norm/M is not less than 1. norm/M = 1566.4501268792442
# Rescale incorrect, norm/M is not less than 1. norm/M = 1617.04777294921
# Rescale incorrect, norm/M is not less than 1. norm/M = 1967.0313450730773
# Rescale incorrect, norm/M is not less than 1. norm/M = 1038.8674121368906
# Rescale incorrect, norm/M is not less than 1. norm/M = 842.2410581300344
# Rescale incorrect, norm/M is not less than 1. norm/M = 1709.5020656612264
# Rescale incorrect, norm/M is not less than 1. norm/M = 711.4691665841887
# Rescale incorrect, norm/M is not less than 1. norm/M = 833.7413792657769
# Rescale incorrect, norm/M is not less than 1. norm/M = 1150.6355309132427
# Rescale incorrect, norm/M is not less than 1. norm/M = 605.8082926966252
# Rescale incorrect, norm/M is not less than 1. norm/M = 964.1008764646986
# Rescale incorrect, norm/M is not less than 1. norm/M = 1475.4063846954168
# Rescale incorrect, norm/M is not less than 1. norm/M = 1932.6590490823776
# Rescale incorrect, norm/M is not less than 1. norm/M = 1660.7641878063243
# Rescale incorrect, norm/M is not less than 1. norm/M = 1402.0556559923004
# Rescale incorrect, norm/M is not less than 1. norm/M = 920.8739395270126
# Rescale incorrect, norm/M is not less than 1. norm/M = 456.2744513995935
# Rescale incorrect, norm/M is not less than 1. norm/M = 1725.1695025417068
# Rescale incorrect, norm/M is not less than 1. norm/M = 616.8012747230667
# Rescale incorrect, norm/M is not less than 1. norm/M = 1712.550583194552
# Rescale incorrect, norm/M is not less than 1. norm/M = 513.5928591793308
# Rescale incorrect, norm/M is not less than 1. norm/M = 948.0324361539535
# Rescale incorrect, norm/M is not less than 1. norm/M = 1991.5523467888058
# Rescale incorrect, norm/M is not less than 1. norm/M = 1014.2753570899769
# Rescale incorrect, norm/M is not less than 1. norm/M = 1818.12743640263
# Rescale incorrect, norm/M is not less than 1. norm/M = 1727.8154740885961
# Rescale incorrect, norm/M is not less than 1. norm/M = 1313.3502722046392
# Rescale incorrect, norm/M is not less than 1. norm/M = 2010.3810739509065
# Rescale incorrect, norm/M is not less than 1. norm/M = 1108.077473600109
# Rescale incorrect, norm/M is not less than 1. norm/M = 1446.002550136064
# Rescale incorrect, norm/M is not less than 1. norm/M = 993.0348055330186
# Rescale incorrect, norm/M is not less than 1. norm/M = 675.2368103117602
# Rescale incorrect, norm/M is not less than 1. norm/M = 1096.0635531300181
# Rescale incorrect, norm/M is not less than 1. norm/M = 1149.5365914141228
# Rescale incorrect, norm/M is not less than 1. norm/M = 596.5880593005529
# Rescale incorrect, norm/M is not less than 1. norm/M = 952.3390612066692
# Rescale incorrect, norm/M is not less than 1. norm/M = 1015.3158683385186
# Rescale incorrect, norm/M is not less than 1. norm/M = 1623.4357663609608
# Rescale incorrect, norm/M is not less than 1. norm/M = 1171.0463270084579
# Rescale incorrect, norm/M is not less than 1. norm/M = 1670.5883507016324
# Rescale incorrect, norm/M is not less than 1. norm/M = 1021.4860192386384
# Rescale incorrect, norm/M is not less than 1. norm/M = 837.1151727809023
# Rescale incorrect, norm/M is not less than 1. norm/M = 1709.061474903697
# Rescale incorrect, norm/M is not less than 1. norm/M = 895.0611012662766
# Rescale incorrect, norm/M is not less than 1. norm/M = 1629.7087738304656
# Rescale incorrect, norm/M is not less than 1. norm/M = 737.4590666606521
# Rescale incorrect, norm/M is not less than 1. norm/M = 876.3810886252624
# Rescale incorrect, norm/M is not less than 1. norm/M = 684.4249867589581
# Rescale incorrect, norm/M is not less than 1. norm/M = 1752.5108416212438
# Rescale incorrect, norm/M is not less than 1. norm/M = 1368.4902036551084
# Rescale incorrect, norm/M is not less than 1. norm/M = 672.7334167409851
# Rescale incorrect, norm/M is not less than 1. norm/M = 1648.2378469140915
# Rescale incorrect, norm/M is not less than 1. norm/M = 1192.3252230410963
# Rescale incorrect, norm/M is not less than 1. norm/M = 1059.3628981609654
# Rescale incorrect, norm/M is not less than 1. norm/M = 1686.261211971621
# Rescale incorrect, norm/M is not less than 1. norm/M = 990.0671378750029
# Rescale incorrect, norm/M is not less than 1. norm/M = 1089.5636741374963
# Rescale incorrect, norm/M is not less than 1. norm/M = 523.6243882784681
# Rescale incorrect, norm/M is not less than 1. norm/M = 871.7922630994152
# Rescale incorrect, norm/M is not less than 1. norm/M = 1109.651606361204
# Rescale incorrect, norm/M is not less than 1. norm/M = 1337.216161471286
# Rescale incorrect, norm/M is not less than 1. norm/M = 1408.1202674132633
# Rescale incorrect, norm/M is not less than 1. norm/M = 486.33591785925086
# Rescale incorrect, norm/M is not less than 1. norm/M = 1627.3514909201392
# Rescale incorrect, norm/M is not less than 1. norm/M = 566.2414458515025
# Rescale incorrect, norm/M is not less than 1. norm/M = 670.7326684305752
# Rescale incorrect, norm/M is not less than 1. norm/M = 955.1461275637357
# Rescale incorrect, norm/M is not less than 1. norm/M = 994.0253392142477
# Rescale incorrect, norm/M is not less than 1. norm/M = 1972.9790451244028
# Rescale incorrect, norm/M is not less than 1. norm/M = 853.5898824962724
# Rescale incorrect, norm/M is not less than 1. norm/M = 571.2765858146122
# Rescale incorrect, norm/M is not less than 1. norm/M = 765.2779723734377
# Rescale incorrect, norm/M is not less than 1. norm/M = 1269.181970798514
# Rescale incorrect, norm/M is not less than 1. norm/M = 1449.1677568521873
# Rescale incorrect, norm/M is not less than 1. norm/M = 786.6170446920153
# Rescale incorrect, norm/M is not less than 1. norm/M = 711.0980066066843
# Rescale incorrect, norm/M is not less than 1. norm/M = 1032.7810150269029
# Rescale incorrect, norm/M is not less than 1. norm/M = 1713.351485393467
# Rescale incorrect, norm/M is not less than 1. norm/M = 318.48930515795973
# Rescale incorrect, norm/M is not less than 1. norm/M = 1461.4529799141674
# Rescale incorrect, norm/M is not less than 1. norm/M = 817.5947575052081
# Rescale incorrect, norm/M is not less than 1. norm/M = 576.8657231106733
# Rescale incorrect, norm/M is not less than 1. norm/M = 1577.0393741121368
# Rescale incorrect, norm/M is not less than 1. norm/M = 1032.8496986493242
# Rescale incorrect, norm/M is not less than 1. norm/M = 1669.8523512574398
# Rescale incorrect, norm/M is not less than 1. norm/M = 528.3053686079671
# Rescale incorrect, norm/M is not less than 1. norm/M = 1673.6470655427925
# Rescale incorrect, norm/M is not less than 1. norm/M = 1520.8410502087324
# Rescale incorrect, norm/M is not less than 1. norm/M = 1696.693899175688
# Rescale incorrect, norm/M is not less than 1. norm/M = 1375.928504683292
# Rescale incorrect, norm/M is not less than 1. norm/M = 1286.6973711794083
# Rescale incorrect, norm/M is not less than 1. norm/M = 1547.2161290524346
# Rescale incorrect, norm/M is not less than 1. norm/M = 1108.268074519879
# Rescale incorrect, norm/M is not less than 1. norm/M = 1709.8419334839114
# Rescale incorrect, norm/M is not less than 1. norm/M = 1678.120507442776
# Rescale incorrect, norm/M is not less than 1. norm/M = 827.9818083750391
# Rescale incorrect, norm/M is not less than 1. norm/M = 1176.786461087992
# Rescale incorrect, norm/M is not less than 1. norm/M = 2028.429195214859
# Rescale incorrect, norm/M is not less than 1. norm/M = 1441.7546384527432
# Rescale incorrect, norm/M is not less than 1. norm/M = 874.8477367519447
# Rescale incorrect, norm/M is not less than 1. norm/M = 1037.7477415056128
# Rescale incorrect, norm/M is not less than 1. norm/M = 719.620559739645
# Rescale incorrect, norm/M is not less than 1. norm/M = 1477.6918234192135
# Rescale incorrect, norm/M is not less than 1. norm/M = 757.0687716449544
# Rescale incorrect, norm/M is not less than 1. norm/M = 1341.973942556263
# Rescale incorrect, norm/M is not less than 1. norm/M = 1347.1286594085957
# Rescale incorrect, norm/M is not less than 1. norm/M = 767.7957492067796
# Rescale incorrect, norm/M is not less than 1. norm/M = 944.580793262281
# Rescale incorrect, norm/M is not less than 1. norm/M = 969.3631285540007
# Rescale incorrect, norm/M is not less than 1. norm/M = 1609.7592405387832
# Rescale incorrect, norm/M is not less than 1. norm/M = 1665.7507691728676
# Rescale incorrect, norm/M is not less than 1. norm/M = 1623.7061002533678
# Rescale incorrect, norm/M is not less than 1. norm/M = 529.3325396194721
# Rescale incorrect, norm/M is not less than 1. norm/M = 2050.5129083963357
# Rescale incorrect, norm/M is not less than 1. norm/M = 1772.9686792213786
# Rescale incorrect, norm/M is not less than 1. norm/M = 2126.561161829116
# shape before projection 255
# shape after projection 256

# %%
from qiskit.circuit import Parameter


qubits = 8

feature_map = RawFeatureVector(2**qubits)

ansatz = EfficientSU2(num_qubits=8, reps=1)


# Combining the feature map and ansatz
circuit = QuantumCircuit(qubits)
circuit.compose(feature_map, range(qubits), inplace=True)
circuit.compose(ansatz, range(qubits), inplace=True)

circvis = QuantumCircuit(qubits)
circvis.compose(ansatz, range(qubits), inplace=True)
# Adjust observable for 6 qubits
observable = SparsePauliOp.from_list([("Z" * 8, 1)]) #+ "I" * 7

# we decompose the circuit for the QNN to avoid additional data copying
qnn = EstimatorQNN(
    circuit=circuit,
    observables=observable,
    input_params=feature_map.parameters,
    weight_params=ansatz.parameters,
)

# %%
circvis.decompose().draw("mpl", style="clifford")

# %%
def callback_graph(weights, obj_func_eval):
    clear_output(wait=True)
    objective_func_vals.append(obj_func_eval)
    plt.title("Objective function value against iteration")
    plt.xlabel("Iteration")
    plt.ylabel("Objective function value")
    plt.plot(range(len(objective_func_vals)), objective_func_vals)
    plt.show()

# %%
iters = 200

classifier = NeuralNetworkClassifier(
    qnn,
    optimizer=COBYLA(maxiter=iters),  # Set max iterations here
    callback=callback_graph,
    loss=loss
    # initial_point=initial_point, # if you have one!!
)

# %%
import timeit
import time
# Get the current date and time
# current_datetime = datetime.datetime.now()
timestr = time.strftime("%Y%m%d-%H%M%S")

x = np.asarray(trainX_shoes_final)
y = np.asarray(train_labels)




accum_objective_func_vals = []
train_accs = []
test_accs = []
train_times = []
test_times = []


for i in range(repeats):

    start = timeit.default_timer()
    objective_func_vals = []
    plt.rcParams["figure.figsize"] = (12, 6)
    classifier.fit(x, y)
    stop = timeit.default_timer()
    train_time = stop - start
    
    train_times.append(train_time)
    
    # Create a plot (example plot, replace with your actual plot logic)
    plt.plot(objective_func_vals)
    plt.title('Objective Function Values')
    plt.xlabel('Iterations')
    plt.ylabel('Value')
    plt.savefig(f'Results_shoes/Final/loss{loss}_rep{i}_{Map}_N{qubits}_its{iters}_{timestr}.pdf', format='pdf', bbox_inches='tight')

    accum_objective_func_vals.append(objective_func_vals)
    
    train_acc = np.round(100 * classifier.score(x, y), 2)
    # score classifier
    print(f"Accuracy from the train data : {train_acc}%") 
    train_accs.append(train_acc)
    

    start = timeit.default_timer()
    y_predict = classifier.predict(testX_shoes_final)
    # Stop timer
    stop = timeit.default_timer()
    test_time = stop - start
    test_times.append(test_time)
    
    x = np.asarray(testX_shoes_final)
    y = np.asarray(test_labels)
    
    test_acc = np.round(100 * classifier.score(x, y), 2)
    print(f"Accuracy from the test data : {test_acc}%")
    test_accs.append(test_acc)
    
    # Let's see some examples in our dataset
    fig, ax = plt.subplots(3, 5, figsize=(15, 10), subplot_kw={"xticks": [], "yticks": []})
    for i in range(15):  # Adjusted for 3 rows and 5 columns (3*5 = 15)
        ax[i // 5, i % 5].imshow(np.asarray(testX_shoes_final[i]).reshape(16, 16), aspect="equal")    #, cmap='gray'
        if y_predict[i] == -1:
            ax[i // 5, i % 5].set_title("QCNN predicts - Boot")
        elif y_predict[i] == +1:
            ax[i // 5, i % 5].set_title("QCNN predicts - Sandal")
    plt.subplots_adjust(wspace=0.1, hspace=0.5)
    
    plt.savefig(f'Results_shoes/Final/predictions_rep{i}_{Map}_N{qubits}__its{iters}_{loss}_{timestr}.pdf', format='pdf', bbox_inches='tight')
# Out:
# Accuracy from the train data : 53.33%
# Accuracy from the test data : 53.33%

# %%
train_test_size = len(testX_shoes_final) + len(trainX_shoes_final)
train_test_split_frac =  len(testX_shoes_final) / len(trainX_shoes_final)


accum_objective_func_vals = np.asarray(accum_objective_func_vals)


np.savetxt(f'Data/train_acc/loss{loss}_{Map}_data_N{qubits}_its{iters}_M{M}_size{train_size}_split{train_test_split_frac}_reps{repeats}_{timestr}.txt', accum_objective_func_vals, fmt='%.10f')


train_acc = np.average(train_accs)
test_acc = np.average(test_accs)
train_time = np.average(train_times)
test_time = np.average(test_times)

train_acc_std = np.std(train_accs)
test_acc_std = np.std(test_accs)
train_time_std = np.std(train_times)
test_time_std = np.std(test_times)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 7
#       1 train_test_size = len(testX_shoes_final) + len(trainX_shoes_final)
#       2 train_test_split_frac =  len(testX_shoes_final) / len(trainX_shoes_final)
# ----> 7 accum_objective_func_vals = np.asarray(accum_objective_func_vals)
#      10 np.savetxt(f'Data/train_acc/loss{loss}_{Map}_data_N{qubits}_its{iters}_M{M}_size{train_size}_split{train_test_split_frac}_reps{repeats}_{timestr}.txt', accum_objective_func_vals, fmt='%.10f')
#      13 train_acc = np.average(train_accs)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (10,) + inhomogeneous part.

# %%
import pandas as pd 

# Create a dictionary with the data
data = {
    'Train Acc. avg': [train_acc],
    'Train Acc. std': [train_acc_std],
    'Test Acc.': [test_acc],
    'Test Acc. std': [test_acc_std],
    'Train time' : [train_time],
    'Train time std': [train_time_std],
    'Test time' : [test_time],
    'Test time std': [test_time_std],
    'Optimizer iterations' : [iters],
    'Train and test size' :[train_test_size],
    'Train and test split' :[train_test_split_frac],
    'M':[M],
    'Map':[Map],
    'Reps':[repeats]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv(f'Results_shoes/Final/accuracy_{Map}_data_N{qubits}_its{iters}_{loss}_{timestr}.csv', index=False)

# Display the DataFrame
print(df)
